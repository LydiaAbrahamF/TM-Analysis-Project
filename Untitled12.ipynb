# %% [markdown]
# <a href="https://colab.research.google.com/github/LydiaAbrahamF/TM-Analysis-Project/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to Time Series Forcasting with Statistical Model

# %%
# !pip install statsforecast utilsforecast

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utilsforecast.plotting import plot_series
from utilsforecast.evaluation import evaluate
from utilsforecast.losses import *

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv()
